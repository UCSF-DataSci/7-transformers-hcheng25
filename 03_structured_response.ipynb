# %% [markdown]
# # Part 3: Prompt Engineering Basics
#
# ## Introduction
#
# In this part, you'll experiment with different prompting techniques to improve the quality of responses from Large Language Models (LLMs). You'll compare zero-shot, one-shot, and few-shot prompting approaches and document which works best for different types of questions.
#
# ## Learning Objectives
#
# - Understand different prompting techniques
# - Compare zero-shot, one-shot, and few-shot prompting
# - Analyze the impact of prompt design on response quality
#
# ## Setup

# %%
# Import necessary libraries
import requests
import json

# %% [markdown]
# ## 1. Understanding Prompting Techniques
#
# LLMs can be prompted in different ways to get better responses:
#
# 1. **Zero-shot prompting**: Asking the model a question directly without examples
# 2. **One-shot prompting**: Providing one example before asking your question
# 3. **Few-shot prompting**: Providing multiple examples before asking your question
#
# ## 2. Creating Prompting Templates
#
# Your first task is to create templates for different prompting strategies.

# %%
# Define a question to experiment with
question = "What foods should be avoided by patients with gout?"

# Example for one-shot and few-shot prompting
example_q = "What are the symptoms of gout?"
example_a = "Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe."

# Examples for few-shot prompting
examples = [
    ("What are the symptoms of gout?",
     "Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe."),
    ("How is gout diagnosed?",
     "Gout is diagnosed through physical examination, medical history, blood tests for uric acid levels, and joint fluid analysis to look for urate crystals.")
]

# TODO: Create prompting templates
# Zero-shot template (just the question)
zero_shot_template = "Question: {question}\nAnswer:"

# One-shot template (one example + the question)
one_shot_template = """Question: {example_q}
Answer: {example_a}

Question: {question}
Answer:"""

# Few-shot template (multiple examples + the question)
few_shot_template = """Question: {examples[0][0]}
Answer: {examples[0][1]}

Question: {examples[1][0]}
Answer: {examples[1][1]}

Question: {question}
Answer:"""

# TODO: Format the templates with your question and examples
zero_shot_prompt = zero_shot_template.format(question=question)
one_shot_prompt = one_shot_template.format(example_q=example_q, example_a=example_a, question=question)
# For few-shot, you'll need to format it with the examples list
few_shot_prompt = few_shot_template.format(examples=examples, question=question)

print("Zero-shot prompt:")
print(zero_shot_prompt)
print("\nOne-shot prompt:")
print(one_shot_prompt)
print("\nFew-shot prompt:")
print(few_shot_prompt)
# Out:
# Zero-shot prompt:
# Question: What foods should be avoided by patients with gout?
# Answer:
#
# One-shot prompt:
# Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: What foods should be avoided by patients with gout?
# Answer:
#
# Few-shot prompt:
# Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed through physical examination, medical history, blood tests for uric acid levels, and joint fluid analysis to look for urate crystals.
#
# Question: What foods should be avoided by patients with gout?
# Answer:

# %% [markdown]
# ## 3. Connecting to the LLM API
#
# Next, implement a function to send prompts to an LLM API and get responses.

# %%
from utils.one_off_chat import get_response
import os
from dotenv import load_dotenv

load_dotenv()

print(get_response(prompt=zero_shot_prompt, api_key=os.getenv('API_KEY')))
# Out:
# <think>
# Okay, the user is asking about foods to avoid in gout. First, I need to recall that gout is caused by hyperuricemia leading to uric acid crystal buildup. The main treatment involves managing uric acid levels through diet and medication.
#
# They want a list of avoided foods, but maybe they or someone they care about is newly diagnosed. Their deeper need might be understanding how to adjust their diet to prevent attacks. They might be looking for practical advice, like swapping current foods.
#
# I should start by explaining the key principle: purine-rich foods increase uric acid. But also need to mention that diet alone isn't enough, so they should consult a doctor. That covers compliance and safety.
#
# Then, categorize foods for clarity. Focus on animal proteins since that's a major trigger. Red meat, organs, game meats are high in purines. Then seafood like sardines and anchovies. Also, alcoholic drinks, especially beer and liquor.
#
# Plant-based foods with high-fructose corn syrup? Wait, fructose increases uric acid production. So sugary drinks and processed foods. Should emphasize limiting added sugars even without corn syrup.
#
# Dairy and coffee have mixed evidence; maybe include moderate consumption is okay. But stress that individual responses vary. How about vegetarians? Maybe suggest some plant-based alternatives but note that soy products might be okay.
#
# Fiber from whole grains and legumes can help, but maybe legumes are moderate. Need to clarify that low-fat options are better. Also, mention food preparation methods, like avoiding frying.
#
# Wait, should the user be chewing xanthan gum? No, that's a side note. Maybe focus on avoiding purines more. Also, check portion sizes for some foods, like mushrooms.
#
# High-purine vegetables like spinach don't seem to cause issues. Important to distinguish between plant and animal sources of purines. The user might have heard conflicting info, so clarifying that is key.
#
# Make sure the answer is structured for easy reference, bullet points but since avoiding markdown, use clear headings. Also, provide tips for practical application: read labels, cook at home, moderate intake.
#
# Check for completeness. Did I cover all major categories? Animal proteins, alcohol, fructose, purine-rich plants, fiber sources, etc. Yes. Remind them to consult a professional and list whole grains and certain fish as okay in moderation.
#
# Potential hidden needs: user might want meal ideas, but stick to the question unless asked. Maybe they're looking for quick fixes, so balance with not overemphasizing diet alone. Emphasize medication adherence.
#
# Include hydration as a key habit. Hydration often gets overlooked.
#
# Okay, structure the answer with an intro, food categories, principles, and tips. Keep it informative but avoid medical advice. Make it actionable: "avoid," "limit," "moderate."
# </think>
# Okay, let's break down the foods generally recommended to be avoided or limited by patients with gout (hyperuricemia). The primary goal is to lower uric acid levels, triggered mainly by purine-rich foods, alcohol, and dehydration.
#
# Below is a summary of gout-friendly foods (green), higher purine foods that should be limited or avoided (amber), and beneficial foods to include (blue). This grouping helps visualize dietary patterns and prioritize choices.
#
# | **Food Group** | **Examples** | **Gout-Friendly Level** |
# |----------------|--------------|-------------------------|
# | **Recommended Foods** | Dairy products (low-fat milk, yogurt)¹ | ★<sup>1</sup> |
# |                   | Coffee consumption | ★<sup>1</sup> |
# |                   | Vitamin C-rich foods | ★<sup>1</sup> |
# |                   | Tart cherries | ★<sup>1</sup> |
# |                   | Citrus juices | ★<sup>1</sup> |
# |                   | Moderate alcohol (Diet or sparkling water)¹ | ★<sup>1</sup> |
# | **Foods to Avoid** | | ★<sup>0</sup> |
# |                   | Red meat (beef, pork, lamb) | ★★ |
# |                   | Organ meats (liver, kidney, brain) | ★★★ |
# |                   | Game (deer, elk, bison)¹ | ★★★ |
# |                   | Most seafood and shellfish (sardines, anchovies, mackerel, shrimp, scallops)¹ | ★★ |
# |                   | Processed meats (bacon, sausage, hot dogs) | ★★★ |
# |                   | Alcohol (especially beer and liquor) | ★★★★★ |
# |                   | Sugary sodas and drinks with HFCS¹ | ★★★★★ |
# | **Foods to Limit** | | ★<sup>△</sup> |
# |                   | Some plant-based purines (hops, yeast extract, mushrooms, asparagus, spinach) | ★★ |
# |                   | Purine-containing plant extracts added to food | ★★ |
# |                   | Refined grains (white bread, white rice, sugary cereals) | ★★★ |
# |                   | Distilled liquor¹ | ★★★ |
#
# **Important Notes on Dietary Principles:**
#
# *   **Diet Alone Isn't Enough:** Many people with gout also require medication to effectively manage their uric acid levels. Diet is crucial for prevention and managing symptoms, but it shouldn't replace medication prescribed by a healthcare professional.
# *   **Individual Variation:** Responses to specific foods can vary significantly among individuals. What triggers one person might not affect another. Work with a doctor or registered dietitian for personalized advice.
# *   **Portion Sizes:** Even moderate purine foods should be consumed in moderation. Avoid very large portions.
# *   **Hydration:** Staying extremely well-hydrated (drinking plenty of water throughout the day) helps flush uric acid from the body and is crucial for gout management.
#
# Go to the Food Guide below for a detailed breakdown.

# %%
print(get_response(prompt=one_shot_prompt, api_key=os.getenv('API_KEY')))
# Out:
# <think>
# Okay, let's tackle this question about foods to avoid in gout. The user is asking what foods they should steer clear of, so they might be someone newly diagnosed or managing gout and looking to adjust their diet. I remember that gout is linked to high uric acid levels, which form uric acid crystals in the joints, causing that painful inflammation. So the main goal here is to reduce uric acid production.
#
# First, I need to recall the main dietary triggers. Purines are a big one—both from meats and seafood. Red meats like beef, pork, and lamb have high purine content. Organ meats, basically anything like liver or kidney, are even higher. Then there's poultry, especially chicken and turkey, but probably in moderation. Smoked or processed meats like bacon, sausage, and hot dogs should definitely be avoided too because they're processed and high in purines.
#
# Seafood is tricky. Fish like sardines, mackerel, herring, anchovies—these are all high in purines. But shellfish like shrimp, lobster, and crayfish also count, though maybe in smaller amounts. Surprisingly, anchovies and sardines, whether canned or fresh, are top contributors.
#
# What about plant-based purines? Asparagus is a classic example from the old wives' tale, but yes, it has some purines. Beans, lentils, and mushrooms can also increase uric acid, but maybe not enough to worry about if you're not having a flare. The user might come across conflicting info here, so I need to clarify that while some plant sources are okay, avoiding the meats and seafood is more critical.
#
# Foods to limit are fructose, especially from sugary drinks and juices. Alcohol, especially beer and liquor, is a no-go. Also, high-fructose corn syrup in processed foods. Dairy might help, but I'm not sure if the user knows that low-fat dairy can be beneficial. Maybe mention that full-fat may be okay but low-fat is still fine.
#
# Whey protein supplements are another sneaky source of purines. And dehydration can spike uric acid too, so emphasizing staying hydrated, especially with water, is key. But maybe the user didn't mention if they're drinking enough, so that's an underlying point.
#
# Wait, the user might have deeper needs. They could be looking for a clear, concise list but also want to understand why certain foods affect them. Maybe they’re overwhelmed by conflicting advice online. So structuring the answer with clear categories (meats, seafood, alcohol, processed foods) helps. Highlighting the main triggers first, then the others, makes it easier to follow.
#
# Also, they might be concerned about maintaining their current diet but minimizing attacks. So mentioning that moderate amounts of poultry, most fish, and avoiding trigger foods is a balance. They might need reassurance that some foods like coffee and tea are okay, which is a positive addition they can include in their diet.
#
# I should double-check recent guidelines. Some sources say plant purines are less problematic, so they don’t need strict avoidance but moderation is still key. Emphasizing personalized advice from a doctor or dietitian is important because individual triggers can vary. Maybe they need help consulting a professional but don’t know how to approach it. Encouraging them to discuss with their doctor could be a proactive step.
#
# In summary, the answer should list the main dietary avoidances, explain the reasons, and subtly guide them towards a manageable diet plan without feeling overwhelmed. Making sure to highlight hydration and consulting healthcare providers to address any unspoken needs they might have.
# </think>
# Foods that should generally be avoided or limited by patients with gout, primarily due to their high purine content (which can increase uric acid levels), include:
#
# 1.  **Red Meat:**
#     *   Beef (especially organ meats like liver, kidney, sweetbread)
#     *   Lamb
#     *   Venison
#
# 2.  **Poultry:**
#     *   Chicken
#     *   Turkey
#     *   Duck (should be limited)
#
# 3.  **Organ Meats:** As noted under red meat, but worth repeating for emphasis (liver, kidney, heart, brain).
#
# 4.  **Processed Meats:** Most types, including:
#     *   Sausages
#     *   Bacon
#     *   Ham
#     *   Corned beef
#     *   Pastrami (a type of smoked beef)
#
# 5.  **Seafood (Some are major triggers):**
#     *   Anchovies
#     *   Sardines
#     *   Mackerel
#     *   Herring
#     *   Grilled, broiled, or fried fish on the bone (like sardines in water). Some lean fish (like salmon, trout, haddock, cod) are considered safe in moderation, but the list above is specific for high-purine options.
#
# 6.  **Foods with Added Sugars/Fructose:**
#     *   High-fructose corn syrup (HFCS) is a major trigger.
#     *   Sugary drinks (soda, sweet tea, energy drinks, juice)
#     *   Candy, desserts, and other sweets.
#     *   Foods like agave nectar (which is high in fructose).
#
# 7.  **Beer and Malt Beverages:** This includes lagers, ales, and stouts. Even non-alcoholic beer can sometimes trigger flares in sensitive individuals.
#
# 8.  **Distilled Spirits:** Whiskey, bourbon, gin, vodka. Some evidence suggests this has less impact than beer or wine, but excessive alcohol intake in general is problematic. Wine (both red and white) should also be considered an occasional trigger for some and avoided during flare-ups.
#
# 9.  **Certain Vegetables (Moderation is often recommended, but limit intake if sensitive):**
#     *   **Asparagus:** Often singled out due to old wives' tales, it's definitely high in purines. Other high-purine plant foods include: beans (lima beans, pinto beans, kidney beans), lentils, peas, mushrooms, cauliflower, spinach, peas (small and green).
#
# 10. **Whey Protein Supplements:** These are highly concentrated sources of protein and contain high levels of purines.
#
# **Key Takeaways:**
#
# *   **Limit or Avoid:** Red meat, poultry (in large amounts), most seafood (specifically sardines, mackerel, herring, anchovies), alcohol (especially beer, liquor), sugary drinks and foods high in high-fructose corn syrup.
# *   **Limit Purine-rich Vegetables:** Asparagus and legumes (beans, lentils) can be consumed but might exacerbate gout individually.
# *   **Stay Hydrated:** Drink plenty of water, especially if you eat more purine-rich meats.
#
# **It's crucial to work with a doctor or registered dietitian to create a personalized meal plan. Food sensitivities can vary greatly among individuals with gout. They can also provide guidance based on the specific inflammatory triggers you experience.**

# %% [markdown]
# ## 4. Comparing Prompting Strategies
#
# Now, let's compare the different prompting strategies on a set of healthcare questions.

# %%
# List of healthcare questions to test
questions = [
    "What foods should be avoided by patients with gout?",
    "What medications are commonly prescribed for gout?",
    "How can gout flares be prevented?",
    "Is gout related to diet?",
    "Can gout be cured permanently?"
]

# TODO: Compare the different prompting strategies on these questions
# For each question:
# - Create prompts using each strategy
# - Get responses from the LLM
# - Store the results

# %% [markdown]
# ## 5. Evaluating Responses
#
# Create a simple evaluation function to score the responses based on the presence of expected keywords.

# %%
def score_response(response, keywords):
    """Score a response based on the presence of expected keywords"""
    # TODO: Implement the score_response function
    # Example implementation:
    response = response.lower()
    found_keywords = 0
    for keyword in keywords:
        if keyword.lower() in response:
            found_keywords += 1
    return found_keywords / len(keywords) if keywords else 0

# Expected keywords for each question
expected_keywords = {
    "What foods should be avoided by patients with gout?": 
        ["purine", "red meat", "seafood", "alcohol", "beer", "organ meats"],
    "What medications are commonly prescribed for gout?": 
        ["nsaids", "colchicine", "allopurinol", "febuxostat", "probenecid", "corticosteroids"],
    "How can gout flares be prevented?": 
        ["medication", "diet", "weight", "alcohol", "water", "exercise"],
    "Is gout related to diet?": 
        ["yes", "purine", "food", "alcohol", "seafood", "meat"],
    "Can gout be cured permanently?": 
        ["manage", "treatment", "lifestyle", "medication", "chronic"]
}

# TODO: Score the responses and calculate average scores for each strategy
# Determine which strategy performs best overall

# %% [markdown]
# ## 6. Saving Results
#
# Save your results in a structured format for auto-grading.

# %%
# TODO: Save your results to results/part_3/prompting_results.txt
# The file should include:
# - Raw responses for each question and strategy
# - Scores for each question and strategy
# - Average scores for each strategy
# - The best performing strategy

# Example format:
"""
# Prompt Engineering Results

## Question: What foods should be avoided by patients with gout?

### Zero-shot response:
[response text]

### One-shot response:
[response text]

### Few-shot response:
[response text]

--------------------------------------------------

## Scores

```
question,zero_shot,one_shot,few_shot
what_foods_should,0.67,0.83,0.83
what_medications_are,0.50,0.67,0.83
how_can_gout,0.33,0.50,0.67
is_gout_related,0.80,0.80,1.00
can_gout_be,0.40,0.60,0.80

average,0.54,0.68,0.83
best_method,few_shot
```
"""

# %% [markdown]
# ## Progress Checkpoints
#
# 1. **Prompting Templates**:
#    - [ ] Create zero-shot template
#    - [ ] Create one-shot template
#    - [ ] Create few-shot template
#    - [ ] Format templates with questions and examples
#
# 2. **LLM API Integration**:
#    - [ ] Connect to the Hugging Face API
#    - [ ] Test with different prompts
#    - [ ] Handle API errors
#
# 3. **Comparison and Evaluation**:
#    - [ ] Compare strategies on multiple questions
#    - [ ] Score responses based on keywords
#    - [ ] Determine the best strategy
#
# 4. **Results and Documentation**:
#    - [ ] Save results in the required format
#    - [ ] Document your findings
#
# ## What to Submit
#
# 1. Your implementation in a Python script `utils/prompt_comparison.py` that:
#    - Defines the prompting templates
#    - Connects to the Hugging Face API
#    - Compares different prompting strategies
#    - Scores and evaluates the responses
#
# 2. The results of your experiments in `results/part_3/prompting_results.txt` with the format shown above
#
# The auto-grader will check:
# 1. That your results file contains the required sections
# 2. That your scoring logic correctly identifies keyword presence
# 3. That you've correctly calculated average scores
# 4. That you've identified the best performing method
